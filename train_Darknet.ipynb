# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/My Drive/Colab Notebooks/ジャンクション/顔検出/darknet/darknet
# Out:
# /content/drive/My Drive/Colab Notebooks/ジャンクション/顔検出/darknet/darknet

# %%
ls
# Out:
# 3rdparty/       darknet53.conv.74  LICENSE          results/
# backup/         darknet.py         Makefile         scripts/
# bad_label.list  data/              mjpeg_stream.sh  src/
# build/          face/              net_cam_v3.sh    video_v2.sh
# cfg/            image_yolov2.sh    obj/             video_yolov3.sh
# darknet*        image_yolov3.sh    README.md

# %%
# !./darknet detector train cfg/obj.data cfg/yolov3.cfg darknet53.conv.74
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #Darknetの学習を行う
# 300回ぐらいごとに区切らないとcoraboratoryが固まる可能性あり<br>
# 重みファイルは100回ごとにbackup直下のlastのファイルに上書きされる<br>
# lastを別名にしてバックアップとったほうがいい<br>
# 参考https://qiita.com/ha9kberry/items/e7c822dd0874e5a24639

# %%
#学習の実行（初回）
#!./darknet detector train cfg/obj.data cfg/yolov3.cfg darknet53.conv.74
#重みファイルを使い学習の再開
# !./darknet detector train cfg/obj.data cfg/yolov3.cfg backup/01062023_yolov3_last.weights
# Out:
# yolov3
# layer     filters    size              input                output
#    0 ^C
